# %%
import os
import requests
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage, AIMessage, get_buffer_string
from deep_research_from_scratch.prompts import clarify_with_user_instructions
from deep_research_from_scratch.utils import get_today_str

# Initialize Granite 2B
model_path = "ibm-granite/granite3.2:2b"
try: # Look for a locally accessible Ollama server for the model
    response = requests.get(os.getenv("OLLAMA_HOST", "http://127.0.0.1:11434"))
    model = ChatOllama(
        model=model_path,
        num_ctx=65536, # 64K context window
        num_predict=2000, # Set the maximum number of tokens to generate as output.
        temperature=0.0,
    )
except Exception: # Use Replicate for the model
    print("Error in model")

# %%
from langchain_core.messages import HumanMessage

# Prepare prompt
prompt = clarify_with_user_instructions.format(
    messages="Find the best coffee shops in San Francisco",
    date=get_today_str()
)

# Use .invoke() since ChatOllama is not callable
response = model.invoke([
    HumanMessage(content=prompt)
])

# Print the response (usually a string)
print(response)
# Out:
# content='```json\n{\n  "need_clarification": false,\n  "question": "",\n  "verification": "Understood: I will now begin researching and compiling a report on \'the best coffee shops in San Francisco\'. This includes focusing on reputation, customer reviews, unique features, and possibly ratings or awards."\n}\n```' additional_kwargs={} response_metadata={'model': 'ibm/granite3.2:2b', 'created_at': '2026-01-12T10:02:40.786896Z', 'done': True, 'done_reason': 'stop', 'total_duration': 36661491042, 'load_duration': 19584497375, 'prompt_eval_count': 632, 'prompt_eval_duration': 10304973958, 'eval_count': 138, 'eval_duration': 6728586883, 'logprobs': None, 'model_name': 'ibm/granite3.2:2b', 'model_provider': 'ollama'} id='lc_run--019bb1a7-d1ce-7723-b836-9ef9f60e2b17-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 632, 'output_tokens': 138, 'total_tokens': 770}
